# %% [markdown]
# #**Resumen Profesional**
#
# Me llamo **Christian**. Combino experiencia en análisis de datos con formación profesional en ciberseguridad. Disfruto descomponer problemas complejos, diseñar detecciones basadas en datos y colaborar para fortalecer controles y respuesta ante incidentes.
#
# Soy **Analista de datos** con experiencia práctica en **Microsoft Excel**, **SQL**, **Python** y **visualización de datos**. Poseo una mentalidad analítica orientada a **resolver problemas** y a **transformar datos** en decisiones accionables. Me encuentro transicionando hacia **Ciberseguridad** completando el **Certificado Profesional en Ciberseguridad de Google** en Coursera, obteniendo fundamentos en **gestión de riesgos**, **controles de seguridad**, **respuesta a incidentes** y **buenas prácticas operativas**. Busco un **puesto de nivel inicial** en ciberseguridad donde pueda aplicar su experiencia en **análisis de datos** para detectar anomalías, automatizar procesos de monitoreo y mejorar la postura de seguridad de una organización.
